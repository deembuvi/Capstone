# %% [markdown]
# # DATA UNDERSTANDING

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset
df=pd.read_csv (r'C:\Users\Lenovo\Documents\CAPSTONE MORINGA PROJECT\Combined_Jobs_Final.csv')

# %%
#Displaying the first 5 rows of the dataset
df.head()
# Out:
#    Job.ID  Provider Status                                               Slug  \
# 0     111         1   open                    palo-alto-ca-tacolicious-server
# 1     113         1   open    san-francisco-ca-claude-lane-kitchen-staff-chef
# 2     117         1   open  san-francisco-ca-machka-restaurants-corp-barte...
# 3     121         1   open                  brisbane-ca-teriyaki-house-server
# 4     127         1   open  los-angeles-ca-rosa-mexicano-sunset-kitchen-st...
#
#                                          Title            Position  \
# 0                         Server @ Tacolicious              Server
# 1             Kitchen Staff/Chef @ Claude Lane  Kitchen Staff/Chef
# 2         Bartender @ Machka Restaurants Corp.           Bartender
# 3                      Server @ Teriyaki House              Server
# 4  Kitchen Staff/Chef @ Rosa Mexicano - Sunset  Kitchen Staff/Chef
#
#                     Company           City  State.Name State.Code  ...  \
# ...

# %%
#Displaying the last 5 rows of the dataset
df.tail()
# Out:
#        Job.ID  Provider Status  \
# 84085      82         1   open
# 84086      83         1   open
# 84087      84         1   open
# 84088      88         1   open
# 84089      92         1   open
#
#                                                     Slug  \
# 84085  san-francisco-ca-national-japanese-american-hi...
# 84086       larkspur-ca-emporio-rulli-kitchen-staff-chef
# 84087                san-francisco-ca-onigilly-driver-84
# 84088  san-francisco-ca-machka-restaurants-corp-line-...
# 84089               san-jose-ca-kazoo-restaurant-cashier
#
#                                                    Title            Position  \
# 84085  Book Keeper @ National Japanese American Histo...         Book Keeper
# 84086                 Kitchen Staff/Chef @ Emporio Rulli  Kitchen Staff/Chef
# 84087                                  Driver @ Onigilly              Driver
# 84088               Line Cook @ Machka Restaurants Corp.           Line Cook
# ...

# %%
#checking for rows and columns
df.shape
# Out:
# (84090, 23)

# %%
#basic info about the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84090 entries, 0 to 84089
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job.ID              84090 non-null  int64
#  1   Provider            84090 non-null  int64
#  2   Status              84090 non-null  object
#  3   Slug                84090 non-null  object
#  4   Title               84090 non-null  object
#  5   Position            84090 non-null  object
#  6   Company             81819 non-null  object
#  7   City                83955 non-null  object
#  8   State.Name          83919 non-null  object
#  9   State.Code          83919 non-null  object
#  10  Address             36 non-null     object
#  11  Latitude            84090 non-null  float64
#  12  Longitude           84090 non-null  float64
#  13  Industry            267 non-null    object
#  14  Job.Description     84034 non-null  object
# ...

# %%
#getting the column names
df.columns
# Out:
# Index(['Job.ID', 'Provider', 'Status', 'Slug', 'Title', 'Position', 'Company',
#        'City', 'State.Name', 'State.Code', 'Address', 'Latitude', 'Longitude',
#        'Industry', 'Job.Description', 'Requirements', 'Salary',
#        'Listing.Start', 'Listing.End', 'Employment.Type', 'Education.Required',
#        'Created.At', 'Updated.At'],
#       dtype='object')

# %%
#dropping columns 
columns_to_drop = ['Latitude', 'Longitude', 'Provider', 'Job.ID']
df = df.drop(columns=columns_to_drop)
print(df)
# Out:
#       Status                                               Slug  \
# 0       open                    palo-alto-ca-tacolicious-server
# 1       open    san-francisco-ca-claude-lane-kitchen-staff-chef
# 2       open  san-francisco-ca-machka-restaurants-corp-barte...
# 3       open                  brisbane-ca-teriyaki-house-server
# 4       open  los-angeles-ca-rosa-mexicano-sunset-kitchen-st...
# ...      ...                                                ...
# 84085   open  san-francisco-ca-national-japanese-american-hi...
# 84086   open       larkspur-ca-emporio-rulli-kitchen-staff-chef
# 84087   open                san-francisco-ca-onigilly-driver-84
# 84088   open  san-francisco-ca-machka-restaurants-corp-line-...
# 84089   open               san-jose-ca-kazoo-restaurant-cashier
#
#                                                    Title            Position  \
# 0                                   Server @ Tacolicious              Server
# ...

# %%
#displaying the first 5 rows of the data set after dropping columns
df.head()
# Out:
#   Status                                               Slug  \
# 0   open                    palo-alto-ca-tacolicious-server
# 1   open    san-francisco-ca-claude-lane-kitchen-staff-chef
# 2   open  san-francisco-ca-machka-restaurants-corp-barte...
# 3   open                  brisbane-ca-teriyaki-house-server
# 4   open  los-angeles-ca-rosa-mexicano-sunset-kitchen-st...
#
#                                          Title            Position  \
# 0                         Server @ Tacolicious              Server
# 1             Kitchen Staff/Chef @ Claude Lane  Kitchen Staff/Chef
# 2         Bartender @ Machka Restaurants Corp.           Bartender
# 3                      Server @ Teriyaki House              Server
# 4  Kitchen Staff/Chef @ Rosa Mexicano - Sunset  Kitchen Staff/Chef
#
#                     Company           City  State.Name State.Code Address  \
# 0               Tacolicious      Palo Alto  California         CA     NaN
# ...

# %%
#summary statistics of numerical columns
print(df.describe())
# Out:
#        Requirements      Salary
# count           0.0  229.000000
# mean            NaN    7.832227
# std             NaN    7.566016
# min             NaN    0.000000
# 25%             NaN    0.000000
# 50%             NaN    8.000000
# 75%             NaN   10.550000
# max             NaN   58.000000

# %%
#checking for the data types
print(df.dtypes)
# Out:
# Status                 object
# Slug                   object
# Title                  object
# Position               object
# Company                object
# City                   object
# State.Name             object
# State.Code             object
# Address                object
# Industry               object
# Job.Description        object
# Requirements          float64
# Salary                float64
# Listing.Start          object
# Listing.End            object
# Employment.Type        object
# Education.Required     object
# Created.At             object
# Updated.At             object
# dtype: object

# %%
#checking for duplicate rows
print(df.duplicated().sum())
# Out:
# 0

# %%
#checking for missing values
print(df.isnull().sum())
# Out:
# Status                    0
# Slug                      0
# Title                     0
# Position                  0
# Company                2271
# City                    135
# State.Name              171
# State.Code              171
# Address               84054
# Industry              83823
# Job.Description          56
# Requirements          84090
# Salary                83861
# Listing.Start           683
# Listing.End             167
# Employment.Type          10
# Education.Required      267
# Created.At                0
# Updated.At                0
# dtype: int64

# %%
#frequency distribution for categorical columns
print('\nFrequency Distribution of Categorical Columns')
categorical_columns= df.select_dtypes(include=['object', 'category']).columns
for column in categorical_columns:
    print(f'\n{column} value counts:')
    print(df[column].value_counts())
# Out:
# Frequency Distribution of Categorical Columns
#
# Status value counts:
# open    84090
# Name: Status, dtype: int64
#
# Slug value counts:
# palo-alto-ca-tacolicious-server                                   1
# chicago-il-accountemps-bookkeeper-285606                          1
# north-canton-oh-officeteam-sales-assistant-285604                 1
# fort-lupton-co-accountemps-accounts-payable-clerk                 1
# boston-ma-accountemps-financial-analyst-285602                    1
#                                                                  ..
# arlington-heights-il-duraclean-sales-marketing-representative     1
# worcester-ma-computer-systems-institute-esl-instructor-257558     1
# dunwoody-ga-state-farm-insurance-bank-analytical-college-co-op    1
# charlotte-nc-carolina-home-remodeling-demonstrator                1
# san-jose-ca-kazoo-restaurant-cashier                              1
# Name: Slug, Length: 84090, dtype: int64
#
# Title value counts:
# ...
